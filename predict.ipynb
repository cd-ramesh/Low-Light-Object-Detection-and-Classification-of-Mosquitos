# %% [markdown]
# # YOLOv9e Model for Object Detection & Classification

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 646.8 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.0/800.0 kB 5.5 MB/s eta 0:00:0000:0100:01
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.52 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5689.4/8062.4 GB disk)

# %%
# Load the best weights for YOLOv9e
from ultralytics import YOLO
model = YOLO('/kaggle/input/yolov9e-weights/yolov9e_best_weights.pt')

# %% [markdown]
# ### Load the enhanced test images.

# %%
import os
import csv
import torch

# Class names
class_names = [
    "aegypti",
    "albopictus",
    "anopheles",
    "culex",
    "culiseta",
    "japonicus/koreicus",
]

# Directory containing enhanced images
source = '/kaggle/input/test-enhanced/test_dark/images'

results = model(source, save=True, max_det=1, conf=0)
# Out:
# image 1/525 /kaggle/input/test-enhanced/test_dark/images/0031063e-716a-4080-934c-77598dc8de72.jpeg: 448x640 1 culex, 77.4ms
# image 2/525 /kaggle/input/test-enhanced/test_dark/images/00fbfad7-9722-4581-831c-79faa576ea7f.jpeg: 448x640 1 albopictus, 77.3ms
# image 3/525 /kaggle/input/test-enhanced/test_dark/images/02043b0e-3d7d-4ca4-a36f-4bf97c344264.jpeg: 448x640 1 culex, 47.0ms
# image 4/525 /kaggle/input/test-enhanced/test_dark/images/0365513c-8f00-44f3-abd0-1fadde81c602.jpeg: 448x640 1 culex, 46.8ms
# image 5/525 /kaggle/input/test-enhanced/test_dark/images/0365d78b-2064-4d54-b15c-994d1950479a.jpeg: 448x640 1 albopictus, 45.7ms
# image 6/525 /kaggle/input/test-enhanced/test_dark/images/03d6749a-c5b3-45a3-81fa-b9c2f09eb4ba.jpeg: 448x640 1 albopictus, 43.1ms
# image 7/525 /kaggle/input/test-enhanced/test_dark/images/03ef458e-8f40-4d42-811b-f3c2db667e12.jpeg: 448x640 1 japonicus/koreicus, 42.3ms
# ...

# %%
# !cd /kaggle/working/

# !zip -r predictions.zip runs/

from IPython.display import FileLink
FileLink(r'predictions.zip')
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/predict/ (stored 0%)
#   adding: runs/detect/predict/d2cfa22b-b242-4cbd-88e9-0de947cc2899.jpeg (deflated 5%)
#   adding: runs/detect/predict/b0d521b6-9476-41ab-9f7a-2b0b0529e362.jpeg (deflated 5%)
#   adding: runs/detect/predict/a4fabc05-3164-465f-9bd3-1964e9b324e2.jpeg (deflated 6%)
#   adding: runs/detect/predict/6e4c95cc-247e-4f17-9419-e4b19f6842eb.jpeg (deflated 6%)
#   adding: runs/detect/predict/b49e20bf-897b-4f0a-bc62-a6f910cf2bb0.jpeg (deflated 7%)
#   adding: runs/detect/predict/8104f0e7-444b-4875-bed1-64a50f723124.jpeg (deflated 7%)
#   adding: runs/detect/predict/5c53c448-8738-4094-aeb8-86d5ed33b2cb.jpeg (deflated 7%)
#   adding: runs/detect/predict/e8e8fe82-6df2-4cf9-be57-1dfa9d5689a1.jpeg (deflated 9%)
#   adding: runs/detect/predict/5bf2ded9-068d-4f0f-beb1-1af0ac2457e4.jpeg (deflated 6%)
#   adding: runs/detect/predict/f64aafcb-e423-4125-85c9-f82d41372e30.jpeg (deflated 6%)
# ...
